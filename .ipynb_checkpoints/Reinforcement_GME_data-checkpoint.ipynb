# %%
# Gym stuff
import gym
import gym_anytrading

# Stable baselines - RL stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Load GME trading data
df = pd.read_csv('gmedata.csv')

# Convert data to datetime type
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes

# Set Date as the index
df.set_index('Date', inplace=True)
df.head()
# Out:
#               Open    High     Low  Close      Volume
# Date
# 2021-03-12  275.00  295.50  262.27  264.5  25,845,900
# 2021-03-11  241.64  281.50  232.60  260.0  28,312,490
# 2021-03-10  269.43  348.50  172.00  265.0  71,570,570
# 2021-03-09  217.71  249.85  208.51  246.9  39,099,328
# 2021-03-08  154.89  210.87  146.10  194.5  63,565,621

# %%
# Create the environment
env = gym.make('stocks-v0', df=df, frame_bound=(5, 100), window_size=5)

# View environment features
env.signal_features

# View environment prices
env.prices
# Out:
# array([264.5 , 260.  , 265.  , 246.9 , 194.5 , 137.74, 132.35, 124.18,
#        118.18, 120.4 , 101.74, 108.73,  91.71,  44.97,  46.  ,  40.59,
#         40.69,  45.94,  49.51,  52.4 ,  51.1 ,  51.2 ,  50.31,  60.  ,
#         63.77,  53.5 ,  92.41,  90.  , 225.  , 325.  , 193.6 , 347.51,
#        147.98,  76.79,  65.01,  43.03,  39.12,  39.36,  35.5 ,  39.91,
#         31.4 ,  19.95,  19.94,  17.69,  18.08,  18.36,  17.37,  17.25,
#         18.84,  19.26,  19.38,  20.99,  20.15,  20.57,  19.46,  15.53,
#         15.63,  14.83,  13.85,  13.85,  12.72,  13.31,  14.12,  13.66,
#         16.94,  16.35,  16.9 ,  16.12,  16.58,  15.8 ,  16.56,  16.08,
#         14.75,  13.67,  13.9 ,  12.71,  12.46,  11.57,  11.63,  12.06,
#         11.01,  11.13,  11.75,  11.1 ,  11.49,  11.86,  11.45,  10.91,
#         11.57,  10.75,  10.47,  11.73,  11.82,  12.69,  13.45,  15.  ,
#         14.91,  14.1 ,  13.86,  13.91])

# %%
# Explore the environment
env.action_space

state = env.reset()
while True:
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done:
        print("info", info)
        break

plt.figure(figsize=(15, 6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -221.87999999999997, 'total_profit': 0.3530249215597311, 'position': 0}

# %%
# Creating our dummy vectorizing environment
env_maker = lambda: gym.make('stocks-v0', df=df, frame_bound=(5, 100), window_size=5)
env = DummyVecEnv([env_maker])

# Initializing and training the A2C model
model = A2C('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 977      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.183   |
# |    explained_variance | -198     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0286   |
# |    value_loss         | 0.54     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 991      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.0215  |
# |    explained_variance | -13.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.73e-05 |
# |    value_loss         | 0.00056  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1001      |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.0123   |
# |    explained_variance | -10.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -2.83e-06 |
# |    value_loss         | 0.000123  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1001     |
# |    iterations         | 400      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.0126  |
# |    explained_variance | -59.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.00156  |
# |    value_loss         | 0.878    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 998      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.00577 |
# |    explained_variance | -18.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -2e-05   |
# |    value_loss         | 0.00135  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1006      |
# |    iterations         | 600       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.00611  |
# |    explained_variance | -29.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -3.35e-06 |
# |    value_loss         | 0.000137  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1009      |
# |    iterations         | 700       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.00178  |
# |    explained_variance | -8.37e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -9.73e-07 |
# |    value_loss         | 0.000607  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1010      |
# |    iterations         | 800       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.000973 |
# |    explained_variance | -463      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -2.15e-06 |
# |    value_loss         | 0.000545  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1007      |
# |    iterations         | 900       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.000765 |
# |    explained_variance | -22.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -6.74e-07 |
# |    value_loss         | 0.000141  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1007     |
# |    iterations         | 1000     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.00119 |
# |    explained_variance | -98.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 3.73e-06 |
# |    value_loss         | 0.00189  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1000      |
# |    iterations         | 1100      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.000777 |
# |    explained_variance | -8.6      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -2.11e-06 |
# |    value_loss         | 0.00121   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 994       |
# |    iterations         | 1200      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.000586 |
# |    explained_variance | -5.43     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -9.53e-07 |
# |    value_loss         | 0.000388  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 1300      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.000651 |
# |    explained_variance | -32       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 1.74e-06  |
# |    value_loss         | 0.00168   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 1400      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.000559 |
# |    explained_variance | -3.93e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 1.24e-06  |
# |    value_loss         | 0.00199   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 1500      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.000329 |
# |    explained_variance | -74.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 3.24e-07  |
# |    value_loss         | 0.000187  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 1600      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.000286 |
# |    explained_variance | -213      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 1.08e-06  |
# |    value_loss         | 0.00252   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 987      |
# |    iterations         | 1700     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.00136 |
# |    explained_variance | -138     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 2.01e-05 |
# |    value_loss         | 0.0127   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 1800      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.000649 |
# |    explained_variance | -121      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -4.97e-06 |
# |    value_loss         | 0.0104    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 1900      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.000671 |
# |    explained_variance | -0.051    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -1.36e-05 |
# |    value_loss         | 0.055     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 986      |
# |    iterations         | 2000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0452  |
# |    explained_variance | -308     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.000548 |
# |    value_loss         | 0.0224   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 988      |
# |    iterations         | 2100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.00105 |
# |    explained_variance | -124     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 2.48e-06 |
# |    value_loss         | 0.00133  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 2200      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.000818 |
# |    explained_variance | -462      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -1.94e-06 |
# |    value_loss         | 0.0018    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 986      |
# |    iterations         | 2300     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.0189  |
# |    explained_variance | 0.0965   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.639    |
# |    value_loss         | 3.25e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 2400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.000251 |
# |    explained_variance | -3.51e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -3.97e-07 |
# |    value_loss         | 0.000733  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 2500      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.000263 |
# |    explained_variance | -54.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 1.11e-06  |
# |    value_loss         | 0.00255   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 2600      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.000564 |
# |    explained_variance | -767      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.000283  |
# |    value_loss         | 68.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 2700      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.000225 |
# |    explained_variance | -180      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -3.89e-07 |
# |    value_loss         | 0.000633  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 2800      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.000241 |
# |    explained_variance | -1.24e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -5.91e-09 |
# |    value_loss         | 4.56e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 2900      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.00061  |
# |    explained_variance | -41.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -4.91e-06 |
# |    value_loss         | 0.0053    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 3000      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.000233 |
# |    explained_variance | -393      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 7.8e-07   |
# |    value_loss         | 0.00171   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 3100      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.000159 |
# |    explained_variance | -5.83e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -1.94e-07 |
# |    value_loss         | 0.000332  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 3200      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.000498 |
# |    explained_variance | -20       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 3.12e-07  |
# |    value_loss         | 0.000271  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 3300      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.000118 |
# |    explained_variance | -64.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 8.37e-07  |
# |    value_loss         | 0.00908   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 3400      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -4.81e-05 |
# |    explained_variance | -16.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -9.03e-08 |
# |    value_loss         | 0.000774  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 3500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -5.04e-05 |
# |    explained_variance | -18.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 3.46e-07  |
# |    value_loss         | 0.00955   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 3600      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -5.43e-05 |
# |    explained_variance | -24.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 3.92e-08  |
# |    value_loss         | 0.000225  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 3700      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -4.32e-05 |
# |    explained_variance | -1.41e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -3.42e-08 |
# |    value_loss         | 0.000435  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 3800      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -4.38e-05 |
# |    explained_variance | -79.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 1.35e-07  |
# |    value_loss         | 0.0024    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 3900      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -6.05e-05 |
# |    explained_variance | -1.02e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -2.23e-07 |
# |    value_loss         | 0.00708   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 4000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -3.81e-05 |
# |    explained_variance | -145      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 8.15e-10  |
# |    value_loss         | 0.00065   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 990       |
# |    iterations         | 4100      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -3.49e-05 |
# |    explained_variance | -1.29     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 1.57e-07  |
# |    value_loss         | 0.00964   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 4200      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.000138 |
# |    explained_variance | -988      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -8.82e-07 |
# |    value_loss         | 0.0294    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 4300      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -4.53e-05 |
# |    explained_variance | -74.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.05e-07  |
# |    value_loss         | 0.00229   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 4400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -4.36e-05 |
# |    explained_variance | -92.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -2.61e-07 |
# |    value_loss         | 0.00879   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 4500      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.000594 |
# |    explained_variance | 0.175     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 0.00842   |
# |    value_loss         | 1.51e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 4600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -2.02e-05 |
# |    explained_variance | -722      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -8.34e-09 |
# |    value_loss         | 0.000576  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 4700      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -2.2e-05  |
# |    explained_variance | -14.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -8.31e-08 |
# |    value_loss         | 0.0029    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 4800      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.000215 |
# |    explained_variance | -313      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -4.74e-08 |
# |    value_loss         | 36.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 986       |
# |    iterations         | 4900      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.49e-05 |
# |    explained_variance | -45.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -7.88e-08 |
# |    value_loss         | 0.00742   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 5000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -1.54e-05 |
# |    explained_variance | -7.36     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 2.73e-08  |
# |    value_loss         | 0.000963  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 5100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.07e-05 |
# |    explained_variance | -78.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 2.34e-05  |
# |    value_loss         | 289       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 5200      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -1.48e-05 |
# |    explained_variance | -188      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -6.23e-08 |
# |    value_loss         | 0.00371   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 5300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.35e-05 |
# |    explained_variance | -560      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -7.67e-09 |
# |    value_loss         | 0.000277  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 5400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -6.2e-05  |
# |    explained_variance | -227      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -5.19e-07 |
# |    value_loss         | 0.0104    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 5500      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.39e-05 |
# |    explained_variance | -28.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -7.65e-09 |
# |    value_loss         | 0.00126   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 5600      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.04e-05 |
# |    explained_variance | -159      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 8.36e-09  |
# |    value_loss         | 0.000375  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 5700      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -3.18e-05 |
# |    explained_variance | -21       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -8.41e-08 |
# |    value_loss         | 0.0101    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 5800      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -1.15e-05 |
# |    explained_variance | -314      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 6.24e-09  |
# |    value_loss         | 0.000427  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 5900      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -8.75e-06 |
# |    explained_variance | -59.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -8.42e-09 |
# |    value_loss         | 0.000599  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6000      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -9.52e-06 |
# |    explained_variance | -54.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | 2.89e-08  |
# |    value_loss         | 0.0122    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6100      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -9.69e-06 |
# |    explained_variance | -75.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -6.63e-08 |
# |    value_loss         | 0.0156    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6200      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -7.95e-06 |
# |    explained_variance | -21.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -2.6e-08  |
# |    value_loss         | 0.00365   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6300      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -8.08e-06 |
# |    explained_variance | -8.8      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 9.58e-09  |
# |    value_loss         | 0.00117   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6400      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -3.54e-05 |
# |    explained_variance | -8.5e+04  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -5.61e-07 |
# |    value_loss         | 0.0406    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6500      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -1.14e-05 |
# |    explained_variance | -1.56e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -5.78e-08 |
# |    value_loss         | 0.00609   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 6600      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -1.11e-05 |
# |    explained_variance | 0.991     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -9.01e-09 |
# |    value_loss         | 0.000685  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 990       |
# |    iterations         | 6700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -7.98e-05 |
# |    explained_variance | -4.38e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -5.34e-06 |
# |    value_loss         | 2.16      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 990       |
# |    iterations         | 6800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -1.02e-05 |
# |    explained_variance | -18.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 1.78e-08  |
# |    value_loss         | 0.00186   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 6900      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -1.02e-05 |
# |    explained_variance | -39.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -4.37e-08 |
# |    value_loss         | 0.00382   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 990       |
# |    iterations         | 7000      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.000157 |
# |    explained_variance | 0.286     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | 0.0023    |
# |    value_loss         | 2.59e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 7100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -5.98e-06 |
# |    explained_variance | -226      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 1.72e-08  |
# |    value_loss         | 0.00204   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 7200      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -6.21e-06 |
# |    explained_variance | -112      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | 1.94e-08  |
# |    value_loss         | 0.0019    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 7300      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1.22e-05 |
# |    explained_variance | -725      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 9.94e-06  |
# |    value_loss         | 403       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 7400      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -5.54e-06 |
# |    explained_variance | -164      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -1.82e-08 |
# |    value_loss         | 0.00216   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 7500      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -6.04e-06 |
# |    explained_variance | -3.13     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | 2.67e-09  |
# |    value_loss         | 0.000139  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 990       |
# |    iterations         | 7600      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.86e-05 |
# |    explained_variance | -9.34     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | 7.41e-06  |
# |    value_loss         | 29.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 7700      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -6.72e-06 |
# |    explained_variance | -246      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -6.55e-08 |
# |    value_loss         | 0.0267    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 7800      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -5.27e-06 |
# |    explained_variance | -108      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -1.44e-08 |
# |    value_loss         | 0.00127   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 7900      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -2.64e-05 |
# |    explained_variance | -290      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 1.52e-06  |
# |    value_loss         | 1.1       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8000      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -5.59e-06 |
# |    explained_variance | -1.19e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | 3.34e-08  |
# |    value_loss         | 0.0355    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 988      |
# |    iterations         | 8100     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -4.2e-06 |
# |    explained_variance | -41.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0       |
# |    value_loss         | 0.000741 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 8200      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -4.71e-06 |
# |    explained_variance | -47.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | 3.02e-08  |
# |    value_loss         | 0.376     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -5.44e-06 |
# |    explained_variance | -71.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -3.82e-08 |
# |    value_loss         | 0.0268    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8400      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -3.93e-06 |
# |    explained_variance | -142      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00111   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8500      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -4.28e-06 |
# |    explained_variance | -1.25     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | 2.75e-08  |
# |    value_loss         | 0.093     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8600      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -7.56e-06 |
# |    explained_variance | -2.04e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -1.48e-07 |
# |    value_loss         | 0.0756    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8700      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -4.16e-06 |
# |    explained_variance | -16.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 6.4e-10   |
# |    value_loss         | 0.000383  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8800      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -4.15e-06 |
# |    explained_variance | 0.992     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -3.09e-09 |
# |    value_loss         | 0.00444   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8900      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -2.77e-05 |
# |    explained_variance | -123      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | 1.38e-06  |
# |    value_loss         | 0.489     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 9000      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -7.02e-06 |
# |    explained_variance | -30.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -6.3e-09  |
# |    value_loss         | 0.000854  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 9100      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 45500     |
# ...
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 197100    |
# |    time_elapsed       | 2755      |
# |    total_timesteps    | 985500    |
# | train/                |           |
# |    entropy_loss       | -1.57e-06 |
# |    explained_variance | -375      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197099    |
# |    policy_loss        | -0        |
# |    value_loss         | 1.77e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 197200    |
# |    time_elapsed       | 2755      |
# |    total_timesteps    | 986000    |
# | train/                |           |
# |    entropy_loss       | -3.75e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197199    |
# |    policy_loss        | -1.5e-07  |
# |    value_loss         | 0.021     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 197300   |
# |    time_elapsed       | 2756     |
# |    total_timesteps    | 986500   |
# | train/                |          |
# |    entropy_loss       | -7.9e-07 |
# |    explained_variance | -9.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197299   |
# |    policy_loss        | -0       |
# |    value_loss         | 8.72e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 197400    |
# |    time_elapsed       | 2756      |
# |    total_timesteps    | 987000    |
# | train/                |           |
# |    entropy_loss       | -9.68e-07 |
# |    explained_variance | -0.338    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197399    |
# |    policy_loss        | -0        |
# |    value_loss         | 4.84e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 197500    |
# |    time_elapsed       | 2757      |
# |    total_timesteps    | 987500    |
# | train/                |           |
# |    entropy_loss       | -1.41e-05 |
# |    explained_variance | 0.998     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197499    |
# |    policy_loss        | -2.87e-07 |
# |    value_loss         | 0.0311    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 197600    |
# |    time_elapsed       | 2757      |
# |    total_timesteps    | 988000    |
# | train/                |           |
# |    entropy_loss       | -7.36e-07 |
# |    explained_variance | -0.674    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197599    |
# |    policy_loss        | -0        |
# |    value_loss         | 6.6e-06   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 197700    |
# |    time_elapsed       | 2758      |
# |    total_timesteps    | 988500    |
# | train/                |           |
# |    entropy_loss       | -8.06e-07 |
# |    explained_variance | -0.0251   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197699    |
# |    policy_loss        | -0        |
# |    value_loss         | 3.07e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 197800    |
# |    time_elapsed       | 2758      |
# |    total_timesteps    | 989000    |
# | train/                |           |
# |    entropy_loss       | -1.26e-06 |
# |    explained_variance | 0.997     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197799    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.118     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 197900    |
# |    time_elapsed       | 2759      |
# |    total_timesteps    | 989500    |
# | train/                |           |
# |    entropy_loss       | -8.73e-07 |
# |    explained_variance | -33.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197899    |
# |    policy_loss        | -0        |
# |    value_loss         | 3.38e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 198000    |
# |    time_elapsed       | 2759      |
# |    total_timesteps    | 990000    |
# | train/                |           |
# |    entropy_loss       | -8.31e-07 |
# |    explained_variance | -189      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197999    |
# |    policy_loss        | -0        |
# |    value_loss         | 5.04e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 198100    |
# |    time_elapsed       | 2760      |
# |    total_timesteps    | 990500    |
# | train/                |           |
# |    entropy_loss       | -6.08e-06 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198099    |
# |    policy_loss        | -4.29e-08 |
# |    value_loss         | 0.0109    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 198200    |
# |    time_elapsed       | 2760      |
# |    total_timesteps    | 991000    |
# | train/                |           |
# |    entropy_loss       | -9.98e-07 |
# |    explained_variance | -0.696    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198199    |
# |    policy_loss        | -0        |
# |    value_loss         | 1.72e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198300    |
# |    time_elapsed       | 2761      |
# |    total_timesteps    | 991500    |
# | train/                |           |
# |    entropy_loss       | -7.61e-07 |
# |    explained_variance | -1.11     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198299    |
# |    policy_loss        | -0        |
# |    value_loss         | 7.92e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198400    |
# |    time_elapsed       | 2761      |
# |    total_timesteps    | 992000    |
# | train/                |           |
# |    entropy_loss       | -3.61e-06 |
# |    explained_variance | 0.997     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198399    |
# |    policy_loss        | -2.21e-08 |
# |    value_loss         | 0.0266    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198500    |
# |    time_elapsed       | 2762      |
# |    total_timesteps    | 992500    |
# | train/                |           |
# |    entropy_loss       | -9.71e-07 |
# |    explained_variance | -195      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198499    |
# |    policy_loss        | -0        |
# |    value_loss         | 1.44e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198600    |
# |    time_elapsed       | 2762      |
# |    total_timesteps    | 993000    |
# | train/                |           |
# |    entropy_loss       | -7.16e-07 |
# |    explained_variance | -4.52     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198599    |
# |    policy_loss        | -0        |
# |    value_loss         | 2.47e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198700    |
# |    time_elapsed       | 2763      |
# |    total_timesteps    | 993500    |
# | train/                |           |
# |    entropy_loss       | -8.54e-07 |
# |    explained_variance | 0.997     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198699    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.0221    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198800    |
# |    time_elapsed       | 2763      |
# |    total_timesteps    | 994000    |
# | train/                |           |
# |    entropy_loss       | -9.55e-07 |
# |    explained_variance | -563      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198799    |
# |    policy_loss        | -0        |
# |    value_loss         | 9.56e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 198900    |
# |    time_elapsed       | 2764      |
# |    total_timesteps    | 994500    |
# | train/                |           |
# |    entropy_loss       | -7.47e-07 |
# |    explained_variance | -10       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198899    |
# |    policy_loss        | -0        |
# |    value_loss         | 9.87e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 199000    |
# |    time_elapsed       | 2764      |
# |    total_timesteps    | 995000    |
# | train/                |           |
# |    entropy_loss       | -8.19e-07 |
# |    explained_variance | -2.07     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198999    |
# |    policy_loss        | -0        |
# |    value_loss         | 24        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199100    |
# |    time_elapsed       | 2765      |
# |    total_timesteps    | 995500    |
# | train/                |           |
# |    entropy_loss       | -5.55e-06 |
# |    explained_variance | -534      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199099    |
# |    policy_loss        | 4.36e-10  |
# |    value_loss         | 5.94e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199200    |
# |    time_elapsed       | 2765      |
# |    total_timesteps    | 996000    |
# | train/                |           |
# |    entropy_loss       | -1.29e-06 |
# |    explained_variance | -10.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199199    |
# |    policy_loss        | -0        |
# |    value_loss         | 2.65e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199300    |
# |    time_elapsed       | 2766      |
# |    total_timesteps    | 996500    |
# | train/                |           |
# |    entropy_loss       | -1.26e-06 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199299    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000272  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199400    |
# |    time_elapsed       | 2766      |
# |    total_timesteps    | 997000    |
# | train/                |           |
# |    entropy_loss       | -2.05e-05 |
# |    explained_variance | -2.44e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199399    |
# |    policy_loss        | -5e-08    |
# |    value_loss         | 0.00086   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199500    |
# |    time_elapsed       | 2767      |
# |    total_timesteps    | 997500    |
# | train/                |           |
# |    entropy_loss       | -1.23e-06 |
# |    explained_variance | 0.0276    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199499    |
# |    policy_loss        | -0        |
# |    value_loss         | 3.64e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199600    |
# |    time_elapsed       | 2767      |
# |    total_timesteps    | 998000    |
# | train/                |           |
# |    entropy_loss       | -1.25e-06 |
# |    explained_variance | -5.38     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199599    |
# |    policy_loss        | -0        |
# |    value_loss         | 2.84e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199700    |
# |    time_elapsed       | 2768      |
# |    total_timesteps    | 998500    |
# | train/                |           |
# |    entropy_loss       | -2.13e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199699    |
# |    policy_loss        | 1.95e-07  |
# |    value_loss         | 0.0141    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199800    |
# |    time_elapsed       | 2768      |
# |    total_timesteps    | 999000    |
# | train/                |           |
# |    entropy_loss       | -7.44e-07 |
# |    explained_variance | -1.49     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199799    |
# |    policy_loss        | -0        |
# |    value_loss         | 1.07e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 199900    |
# |    time_elapsed       | 2769      |
# |    total_timesteps    | 999500    |
# | train/                |           |
# |    entropy_loss       | -7.99e-07 |
# |    explained_variance | -18.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199899    |
# |    policy_loss        | -0        |
# |    value_loss         | 4.25e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 200000    |
# |    time_elapsed       | 2769      |
# |    total_timesteps    | 1000000   |
# | train/                |           |
# |    entropy_loss       | -1.77e-06 |
# |    explained_variance | 0.999     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199999    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00774   |
# -------------------------------------

# %%
env.action_space
# Out:
# Discrete(2)

# %%
state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -8.129999999999999, 'total_profit': 0.22672886730304037, 'position': 1}

# %%
from gym_anytrading.envs import StocksEnv
from finta import TA

# %%
df['Volume']=df['Volume'].apply(lambda x: float(x.replace(",","")))

# %%
df.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
df['SMA'] = TA.SMA(df,12) 
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)
df.fillna(0,inplace=True)

# %%
df.head(15)
# Out:
#               Open    High     Low   Close       Volume         SMA  \
# Date
# 2021-03-12  275.00  295.50  262.27  264.50   25845900.0    0.000000
# 2021-03-11  241.64  281.50  232.60  260.00   28312490.0    0.000000
# 2021-03-10  269.43  348.50  172.00  265.00   71570570.0    0.000000
# 2021-03-09  217.71  249.85  208.51  246.90   39099328.0    0.000000
# 2021-03-08  154.89  210.87  146.10  194.50   63565621.0    0.000000
# 2021-03-05  128.17  151.53  127.50  137.74   30733670.0    0.000000
# 2021-03-04  125.00  147.87  115.30  132.35   32606891.0    0.000000
# 2021-03-03  122.51  127.75  113.12  124.18   19273881.0    0.000000
# 2021-03-02  116.93  133.20  112.20  118.18   33783039.0    0.000000
# 2021-03-01  104.54  133.99   99.97  120.40   49793969.0    0.000000
# 2021-02-26  117.46  142.90   86.00  101.74   92194148.0    0.000000
# 2021-02-25  169.56  184.68  101.00  108.73  150308797.0  172.851667
# 2021-02-24   44.70   91.71   44.70   91.71   83111742.0  158.452500
# 2021-02-23   44.97   46.23   40.00   44.97    7565215.0  140.533333
# 2021-02-22   46.69   48.51   42.40   46.00   19476020.0  122.283333
#
#                   RSI          OBV
# Date
# 2021-03-12   0.000000          0.0
# 2021-03-11   0.000000  -28312490.0
# 2021-03-10  54.474708   43258080.0
# 2021-03-09  17.439298    4158752.0
# 2021-03-08   5.590185  -59406869.0
# 2021-03-05   3.118483  -90140539.0
# 2021-03-04   2.983575 -122747430.0
# 2021-03-03   2.786780 -142021311.0
# 2021-03-02   2.648611 -175804350.0
# 2021-03-01   4.534603 -126010381.0
# 2021-02-26   3.858041 -218204529.0
# 2021-02-25   9.316228  -67895732.0
# 2021-02-24   8.109047 -151007474.0
# 2021-02-23   5.862450 -158572689.0
# 2021-02-22   6.477351 -139096669.0

# %%
def add_signals(env):
    start=env.frame_bound[0] -env.window_size
    end= env.frame_bound[1]
    prices = env.df.loc[:,'Low'].to_numpy()[start:end]
    signal_features=env.df.loc[:,['Low','Volume','SMA','RSI','OBV']].to_numpy()[start:end]
    return prices,signal_features

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals
    
env2 = MyCustomEnv(df=df,window_size=12,frame_bound=(12,50))

# %%
# Creating our dummy vectorizing environment
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# Initializing and training the A2C model
model = A2C('MlpPolicy', env, verbose=1) 
model.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 906      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | 0.0211   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 33.9     |
# |    value_loss         | 1.3e+03  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.379   |
# |    explained_variance | 0.0147   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -9.78    |
# |    value_loss         | 125      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | 0.137    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.36    |
# |    value_loss         | 17.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.223   |
# |    explained_variance | -258     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0283   |
# |    value_loss         | 0.207    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.616   |
# |    explained_variance | -0.0382  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -5.22    |
# |    value_loss         | 74       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | -900     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0363  |
# |    value_loss         | 0.443    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | 0.16     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.529   |
# |    value_loss         | 3.42     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.345   |
# |    explained_variance | -922     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0462  |
# |    value_loss         | 0.6      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 900      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.48    |
# |    explained_variance | 0.0134   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 38.9     |
# |    value_loss         | 2.05e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 1000      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.175    |
# |    explained_variance | -9.12e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.0417   |
# |    value_loss         | 1.52      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.301   |
# |    explained_variance | 0.0211   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 25.3     |
# |    value_loss         | 3.32e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.0707  |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.00604 |
# |    value_loss         | 1.72     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 933      |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | 0.138    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 4.52     |
# |    value_loss         | 1.97e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 932      |
# |    iterations         | 1400     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.0421  |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0103  |
# |    value_loss         | 4.92     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 933      |
# |    iterations         | 1500     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.0798  |
# |    explained_variance | 0.316    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 1.49     |
# |    value_loss         | 7.37e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 932      |
# |    iterations         | 1600     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.0416  |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.00649  |
# |    value_loss         | 2.11     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 1700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.0369  |
# |    explained_variance | 0.396    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.701    |
# |    value_loss         | 4.39e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 1800     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.16     |
# |    value_loss         | 14.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 1900      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.0119   |
# |    explained_variance | -2.28e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -0.042    |
# |    value_loss         | 268       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 2000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.151   |
# |    explained_variance | -11.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.465    |
# |    value_loss         | 14.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 2100      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.0211   |
# |    explained_variance | -2.52e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.00386  |
# |    value_loss         | 0.834     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 2200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.0983  |
# |    explained_variance | -12.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 1.34     |
# |    value_loss         | 7.44     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 2300      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.00506  |
# |    explained_variance | -177      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -0.000675 |
# |    value_loss         | 1.2       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 2400     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.276   |
# |    explained_variance | 0.56     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.781    |
# |    value_loss         | 21.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 2500      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.00033  |
# |    explained_variance | -61.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -5.25e-06 |
# |    value_loss         | 0.0337    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 2600     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.253   |
# |    explained_variance | 0.527    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.569    |
# |    value_loss         | 16.4     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 2700      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.000182 |
# |    explained_variance | -971      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -3.57e-06 |
# |    value_loss         | 0.277     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 2800     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.125   |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -1.28    |
# |    value_loss         | 3.28     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 2900      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.000437 |
# |    explained_variance | -53.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 2.18e-06  |
# |    value_loss         | 0.0627    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 933      |
# |    iterations         | 3000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00711  |
# |    value_loss         | 0.0493   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 931       |
# |    iterations         | 3100      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.000532 |
# |    explained_variance | -600      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 1.62e-06  |
# |    value_loss         | 0.0745    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 3200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.169   |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0407  |
# |    value_loss         | 0.2      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 931       |
# |    iterations         | 3300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.000153 |
# |    explained_variance | -159      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 1.19e-05  |
# |    value_loss         | 0.566     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 929      |
# |    iterations         | 3400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.0664  |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0029  |
# |    value_loss         | 0.103    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 929       |
# |    iterations         | 3500      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.000537 |
# |    explained_variance | -488      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -6.3e-05  |
# |    value_loss         | 0.803     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 3600     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.277   |
# |    explained_variance | -0.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.347    |
# |    value_loss         | 9.04     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 932       |
# |    iterations         | 3700      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.00146  |
# |    explained_variance | -2.86e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.000219 |
# |    value_loss         | 0.594     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 3800     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.0443  |
# |    explained_variance | -0.0726  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0181   |
# |    value_loss         | 7.41     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 3900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.000179 |
# |    explained_variance | -8.46e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 8.59e-06  |
# |    value_loss         | 0.299     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 4000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.109   |
# |    explained_variance | 0.48     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0632  |
# |    value_loss         | 5.41     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 4100      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.000152 |
# |    explained_variance | -1.55e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -1.98e-06 |
# |    value_loss         | 0.148     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 4200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.102   |
# |    explained_variance | 0.172    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 3.55     |
# |    value_loss         | 1.78e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 4300      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.000303 |
# |    explained_variance | -137      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -1.35e-05 |
# |    value_loss         | 0.131     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 4400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.184   |
# |    explained_variance | 0.0208   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 8.7      |
# |    value_loss         | 1.48e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 4500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.00343  |
# |    explained_variance | -2.21e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -6.68e-05 |
# |    value_loss         | 0.238     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 4600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.0233  |
# |    explained_variance | 0.0109   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.328    |
# |    value_loss         | 1.06e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 4700     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.00599 |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0009  |
# |    value_loss         | 1.24     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 4800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.0106  |
# |    explained_variance | 0.00748  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.156    |
# |    value_loss         | 1.3e+04  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 4900     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.00785 |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00192 |
# |    value_loss         | 2.69     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 5000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.0151  |
# |    explained_variance | 0.516    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.211    |
# |    value_loss         | 6.78e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 5100      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.00235  |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -0.000311 |
# |    value_loss         | 1.16      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 5200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.019   |
# |    explained_variance | 0.932    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.11     |
# |    value_loss         | 753      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 5300      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.0171   |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -0.000526 |
# |    value_loss         | 0.0301    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 5400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.0204  |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.072    |
# |    value_loss         | 445      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 5500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.00835 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.000422 |
# |    value_loss         | 0.34     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 5600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.0025  |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.000743 |
# |    value_loss         | 160      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 5700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.02    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.000226 |
# |    value_loss         | 0.0712   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 5800      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.00211  |
# |    explained_variance | -9.33e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 3.44e-05  |
# |    value_loss         | 0.52      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 5900     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.029   |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.00147 |
# |    value_loss         | 0.0757   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 6000      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.00423  |
# |    explained_variance | -2.95e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | 4.22e-05  |
# |    value_loss         | 0.757     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 6100     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.162   |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.109    |
# |    value_loss         | 0.0709   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 6200      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -9.54e-05 |
# |    explained_variance | -745      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | 2.87e-06  |
# |    value_loss         | 0.165     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 6300     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.183   |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.0011   |
# |    value_loss         | 0.00322  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 6400      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -7.55e-05 |
# |    explained_variance | -3.84e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -2.49e-07 |
# |    value_loss         | 0.47      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 6500     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.0903  |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00684 |
# |    value_loss         | 0.0186   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 6600      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -5.32e-05 |
# |    explained_variance | -3.67e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.85e-07  |
# |    value_loss         | 0.681     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 6700     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.172   |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.0331   |
# |    value_loss         | 0.109    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 6800      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.000162 |
# |    explained_variance | -696      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 1.56e-05  |
# |    value_loss         | 0.706     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 6900     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.12    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.0302  |
# |    value_loss         | 0.595    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 7000      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -7.04e-05 |
# |    explained_variance | -488      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -2.82e-06 |
# |    value_loss         | 0.329     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 7100      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.00506  |
# |    explained_variance | 0.963     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000941 |
# |    value_loss         | 2.08      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 7200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -5.38e-05 |
# |    explained_variance | -3.28e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -1.14e-05 |
# |    value_loss         | 3.29      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 7300     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.0261  |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.0204   |
# |    value_loss         | 6.95     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 7400      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -5.09e-05 |
# |    explained_variance | -466      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -1.28e-06 |
# |    value_loss         | 0.261     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 7500     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.415    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.165   |
# |    value_loss         | 1.86     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 7600      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.34e-05 |
# |    explained_variance | -467      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -1.36e-09 |
# |    value_loss         | 0.378     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 7700     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.0516  |
# |    explained_variance | 0.0958   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | -0.0283  |
# |    value_loss         | 2.17     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 7800      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -2.49e-05 |
# |    explained_variance | -288      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | 6.64e-07  |
# |    value_loss         | 0.278     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 7900     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.0283  |
# |    explained_variance | 0.166    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 0.608    |
# |    value_loss         | 1.46e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 8000      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -1.59e-05 |
# |    explained_variance | -800      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | 1.01e-06  |
# |    value_loss         | 1.83      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 8100     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.0457  |
# |    explained_variance | 0.0833   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 1.32     |
# |    value_loss         | 1.17e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 8200     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.00377 |
# |    explained_variance | -85.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 0.000159 |
# |    value_loss         | 0.0508   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 8300     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.145   |
# |    explained_variance | 0.0986   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 4.84     |
# |    value_loss         | 8.56e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 8400     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.00103 |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 0.000159 |
# |    value_loss         | 1.55     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 8500     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.0934  |
# |    explained_variance | 0.0889   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -0.508   |
# |    value_loss         | 4.64e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 8600      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -0.00555  |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -0.000118 |
# |    value_loss         | 0.215     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 8700     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.0134  |
# |    explained_variance | -0.621   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | -0.267   |
# |    value_loss         | 1.27e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 8800      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.00446  |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0.000495 |
# |    value_loss         | 0.216     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 8900     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.057   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | -9.07    |
# |    value_loss         | 89.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 933       |
# |    iterations         | 9000      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -0.000516 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -1e-06    |
# |    value_loss         | 0.448     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 933       |
# |    iterations         | 9100      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.011    |
# |    explained_variance | -2.85e+07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -0.00379  |
# |    value_loss         | 8.33e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 933       |
# |    iterations         | 9200      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -0.0081   |
# |    explained_variance | 1         |
# ...
# |    value_loss         | 0.0117    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197100    |
# |    time_elapsed       | 1787      |
# |    total_timesteps    | 985500    |
# | train/                |           |
# |    entropy_loss       | -7.28e-10 |
# |    explained_variance | -5.47e+12 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197099    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00281   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197200    |
# |    time_elapsed       | 1788      |
# |    total_timesteps    | 986000    |
# | train/                |           |
# |    entropy_loss       | -0.000328 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197199    |
# |    policy_loss        | 1.71e-06  |
# |    value_loss         | 0.0287    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197300    |
# |    time_elapsed       | 1789      |
# |    total_timesteps    | 986500    |
# | train/                |           |
# |    entropy_loss       | -7.72e-10 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197299    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00228   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197400    |
# |    time_elapsed       | 1790      |
# |    total_timesteps    | 987000    |
# | train/                |           |
# |    entropy_loss       | -0.000302 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197399    |
# |    policy_loss        | -3.71e-07 |
# |    value_loss         | 0.000152  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197500    |
# |    time_elapsed       | 1791      |
# |    total_timesteps    | 987500    |
# | train/                |           |
# |    entropy_loss       | -7.25e-10 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197499    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00216   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197600    |
# |    time_elapsed       | 1792      |
# |    total_timesteps    | 988000    |
# | train/                |           |
# |    entropy_loss       | -0.000337 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197599    |
# |    policy_loss        | -4.74e-07 |
# |    value_loss         | 0.000768  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197700    |
# |    time_elapsed       | 1793      |
# |    total_timesteps    | 988500    |
# | train/                |           |
# |    entropy_loss       | -3.96e-09 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197699    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.0022    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 197800    |
# |    time_elapsed       | 1794      |
# |    total_timesteps    | 989000    |
# | train/                |           |
# |    entropy_loss       | -1.69e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197799    |
# |    policy_loss        | -1.07e-08 |
# |    value_loss         | 0.000123  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 551      |
# |    iterations         | 197900   |
# |    time_elapsed       | 1795     |
# |    total_timesteps    | 989500   |
# | train/                |          |
# |    entropy_loss       | -5.4e-07 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197899   |
# |    policy_loss        | -0       |
# |    value_loss         | 0.0155   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 198000    |
# |    time_elapsed       | 1796      |
# |    total_timesteps    | 990000    |
# | train/                |           |
# |    entropy_loss       | -1.38e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197999    |
# |    policy_loss        | 5.44e-08  |
# |    value_loss         | 0.000668  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 551      |
# |    iterations         | 198100   |
# |    time_elapsed       | 1797     |
# |    total_timesteps    | 990500   |
# | train/                |          |
# |    entropy_loss       | -5.3e-07 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198099   |
# |    policy_loss        | -0       |
# |    value_loss         | 0.00608  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 198200    |
# |    time_elapsed       | 1798      |
# |    total_timesteps    | 991000    |
# | train/                |           |
# |    entropy_loss       | -6.16e-08 |
# |    explained_variance | -8.79e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198199    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000288  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 198300    |
# |    time_elapsed       | 1799      |
# |    total_timesteps    | 991500    |
# | train/                |           |
# |    entropy_loss       | -2.75e-05 |
# |    explained_variance | 0.999     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198299    |
# |    policy_loss        | -6.96e-07 |
# |    value_loss         | 0.0482    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 198400    |
# |    time_elapsed       | 1800      |
# |    total_timesteps    | 992000    |
# | train/                |           |
# |    entropy_loss       | -6.15e-08 |
# |    explained_variance | -806      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198399    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000932  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 198500    |
# |    time_elapsed       | 1801      |
# |    total_timesteps    | 992500    |
# | train/                |           |
# |    entropy_loss       | -0.000153 |
# |    explained_variance | 0.996     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198499    |
# |    policy_loss        | 5.57e-10  |
# |    value_loss         | 0.0813    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 198600    |
# |    time_elapsed       | 1802      |
# |    total_timesteps    | 993000    |
# | train/                |           |
# |    entropy_loss       | -2.62e-10 |
# |    explained_variance | -814      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198599    |
# |    policy_loss        | -0        |
# |    value_loss         | 6.9e-05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 198700    |
# |    time_elapsed       | 1803      |
# |    total_timesteps    | 993500    |
# | train/                |           |
# |    entropy_loss       | -0.000155 |
# |    explained_variance | 0.996     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198699    |
# |    policy_loss        | 1.82e-06  |
# |    value_loss         | 0.0662    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 198800    |
# |    time_elapsed       | 1804      |
# |    total_timesteps    | 994000    |
# | train/                |           |
# |    entropy_loss       | -1.88e-10 |
# |    explained_variance | -44.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198799    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000501  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 198900    |
# |    time_elapsed       | 1805      |
# |    total_timesteps    | 994500    |
# | train/                |           |
# |    entropy_loss       | -0.000152 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198899    |
# |    policy_loss        | 3.91e-07  |
# |    value_loss         | 0.000876  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199000    |
# |    time_elapsed       | 1806      |
# |    total_timesteps    | 995000    |
# | train/                |           |
# |    entropy_loss       | -4.59e-10 |
# |    explained_variance | -8.22e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198999    |
# |    policy_loss        | -0        |
# |    value_loss         | 9.34e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199100    |
# |    time_elapsed       | 1807      |
# |    total_timesteps    | 995500    |
# | train/                |           |
# |    entropy_loss       | -0.000152 |
# |    explained_variance | 0.999     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199099    |
# |    policy_loss        | -1.55e-09 |
# |    value_loss         | 0.0132    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199200    |
# |    time_elapsed       | 1808      |
# |    total_timesteps    | 996000    |
# | train/                |           |
# |    entropy_loss       | -3.27e-10 |
# |    explained_variance | -2.72e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199199    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000578  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199300    |
# |    time_elapsed       | 1809      |
# |    total_timesteps    | 996500    |
# | train/                |           |
# |    entropy_loss       | -0.000125 |
# |    explained_variance | 0.997     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199299    |
# |    policy_loss        | -1.7e-06  |
# |    value_loss         | 0.054     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199400    |
# |    time_elapsed       | 1810      |
# |    total_timesteps    | 997000    |
# | train/                |           |
# |    entropy_loss       | -3.27e-10 |
# |    explained_variance | -2.09e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199399    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000123  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199500    |
# |    time_elapsed       | 1811      |
# |    total_timesteps    | 997500    |
# | train/                |           |
# |    entropy_loss       | -2.81e-09 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199499    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00373   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 550      |
# |    iterations         | 199600   |
# |    time_elapsed       | 1812     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -3.1e-10 |
# |    explained_variance | -622     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199599   |
# |    policy_loss        | -0       |
# |    value_loss         | 0.000309 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199700    |
# |    time_elapsed       | 1813      |
# |    total_timesteps    | 998500    |
# | train/                |           |
# |    entropy_loss       | -1.12e-08 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199699    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.0288    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199800    |
# |    time_elapsed       | 1814      |
# |    total_timesteps    | 999000    |
# | train/                |           |
# |    entropy_loss       | -5.87e-10 |
# |    explained_variance | -5.04e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199799    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000135  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 199900    |
# |    time_elapsed       | 1815      |
# |    total_timesteps    | 999500    |
# | train/                |           |
# |    entropy_loss       | -1.17e-08 |
# |    explained_variance | 0.998     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199899    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.0413    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 200000    |
# |    time_elapsed       | 1816      |
# |    total_timesteps    | 1000000   |
# | train/                |           |
# |    entropy_loss       | -3.13e-10 |
# |    explained_variance | -2.15e+07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199999    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000128  |
# -------------------------------------

# %%
env = MyCustomEnv(df=df, window_size=12, frame_bound=(80,250))
state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -3.2599999999999993, 'total_profit': 0.3090412969375846, 'position': 1}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
